# %%
# !nvidia-smi
# Out:
# Mon Jul  8 20:26:48 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   53C    P8              10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
# !pip install ultralytics

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.51 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 30.2/78.2 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="28Dts4nbe2jIxkAXVO4K")
project = rf.workspace("sanskar-2tjnr").project("intel-pzad1")
version = project.version(2)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.196 is required but found version=8.2.51, to fix: `pip install ultralytics==8.0.196`

# %%
# !yolo task=detect mode=train model=yolov8s.pt data=/content/INTEL-2/data.yaml epochs=150 imgsz=640 plots=true
# Out:
# Ultralytics YOLOv8.2.51 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=val model=/content/runs/detect/train3/weights/best.pt data=/content/INTEL-2/data.yaml
# Out:
# Ultralytics YOLOv8.2.51 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11126745 parameters, 0 gradients, 28.4 GFLOPs
# val: Scanning /content/INTEL-2/valid/labels.cache... 226 images, 1 backgrounds, 0 corrupt: 100% 226/226 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 15/15 [00:08<00:00,  1.76it/s]
#                    all        226        766      0.988      0.993       0.99      0.928
#                   date        225        225      0.994          1      0.993      0.953
#      number-plate-time        216        325      0.979      0.987      0.985      0.882
#                   time        216        216      0.992      0.991      0.993       0.95
# Speed: 3.1ms preprocess, 11.3ms inference, 0.1ms loss, 4.8ms postprocess per image
# Results saved to runs/detect/val
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %%
# !yolo task=detect mode=predict model=/content/runs/detect/train3/weights/best.pt conf=0.25 source=/content/INTEL-2/test/images
# Out:
# Ultralytics YOLOv8.2.51 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11126745 parameters, 0 gradients, 28.4 GFLOPs
#
# image 1/114 /content/INTEL-2/test/images/frame100_jpg.rf.d90999a813a99ac2d715e331ad0c1f68.jpg: 640x640 1 date, 1 number-plate-time, 1 time, 16.4ms
# image 2/114 /content/INTEL-2/test/images/frame105_jpg.rf.3a4528c64c472d76ea124ec11fd41507.jpg: 640x640 1 date, 1 number-plate-time, 1 time, 16.4ms
# image 3/114 /content/INTEL-2/test/images/frame109_jpg.rf.84498c72e1a114b0b8206549cf1dc69d.jpg: 640x640 1 date, 1 number-plate-time, 1 time, 16.3ms
# image 4/114 /content/INTEL-2/test/images/frame109_jpg.rf.b77c0bfed13403935c39739727a1c05f.jpg: 640x640 1 date, 1 number-plate-time, 1 time, 16.3ms
# image 5/114 /content/INTEL-2/test/images/frame110_jpg.rf.e38175b1916b144c0ff9aff966041fe0.jpg: 640x640 1 date, 1 number-plate-time, 1 time, 16.3ms
# ...

# %%
# !yolo task=detect mode=predict model=/content/runs/detect/train6/weights/best.pt conf=0.25 source=/content/car4.mp4
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/yolo", line 8, in <module>
#     sys.exit(entrypoint())
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/cfg/__init__.py", line 681, in entrypoint
#     model = YOLO(model, task=task)
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/models/yolo/model.py", line 23, in __init__
#     super().__init__(model=model, task=task, verbose=verbose)
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/engine/model.py", line 149, in __init__
#     self._load(model, task=task)
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/engine/model.py", line 230, in _load
#     self.model, self.ckpt = attempt_load_one_weight(weights)
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/nn/tasks.py", line 855, in attempt_load_one_weight
#     ckpt, weight = torch_safe_load(weight)  # load ckpt
# ...
